# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve

import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Conv1D, MaxPooling1D, BatchNormalization, GlobalAveragePooling1D
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

import warnings
warnings.filterwarnings("ignore")

# %%
MAX_LEN = 420
EPOCHS = 20
BATCH_SIZE = 16

# %%
# Load the dataset
mfcc_df = pd.read_csv('features/mfcc_labels.csv')
mfcc_df.head()
# Out:
#                                             filepath  label
# 0  C:\Users\RadhaKrishna\Downloads\Real-time scam...      0
# 1  C:\Users\RadhaKrishna\Downloads\Real-time scam...      0
# 2  C:\Users\RadhaKrishna\Downloads\Real-time scam...      0
# 3  C:\Users\RadhaKrishna\Downloads\Real-time scam...      0
# 4  C:\Users\RadhaKrishna\Downloads\Real-time scam...      0

# %%
mfcc_df.label.value_counts(normalize=True)
# Out:
# label
# 1    0.633907
# 0    0.366093
# Name: proportion, dtype: float64

# %%
def pad_features(features, max_len=MAX_LEN):
    if features.shape[0] < max_len:
        padding = np.zeros((max_len - features.shape[0], features.shape[1]))
        features = np.vstack((features, padding))
    else:
        features = features[:max_len, :]
    return features

# %%
X = []
y = []
for _, row in mfcc_df.iterrows():
    mfcc = np.load(row['filepath'])
    mfcc = pad_features(mfcc)
    X.append(mfcc)
    y.append(row['label'])

X = np.array(X)
y = np.array(y)

# %%
X.shape, y.shape
# Out:
# ((407, 420, 120), (407,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((325, 420, 120), (82, 420, 120), (325,), (82,))

# %%
X_train.shape[1:]
# Out:
# (420, 120)

# %%
model = Sequential()

model.add(Conv1D(64, kernel_size=5, activation='relu',
                 input_shape=X_train.shape[1:]))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.3))

model.add(Conv1D(128, kernel_size=3, activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.3))

model.add(GlobalAveragePooling1D())

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.4))

model.add(Dense(1, activation='sigmoid'))

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 416, 64)        │        38,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 416, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 208, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 208, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 206, 128)       │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 206, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 103, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 103, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 80,577 (314.75 KB)
#  Trainable params: 80,193 (313.25 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True,
    verbose=1
)

lr_reduction = ReduceLROnPlateau(
    monitor='val_loss',
    patience=2,
    factor=0.5,          # reduce LR by half
    min_lr=1e-6,
    verbose=1
)

model_checkpoint = ModelCheckpoint(
    filepath='models/best_phoneme_model.keras',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

# %%
history = model.fit(
    X_train, y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
    callbacks=[early_stop, lr_reduction, model_checkpoint]
)
# Out:
# Epoch 1/20
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5987 - loss: 0.6644
# Epoch 1: val_accuracy improved from None to 0.63415, saving model to models/best_phoneme_model.keras
#
# Epoch 1: finished saving model to models/best_phoneme_model.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.6215 - loss: 0.6491 - val_accuracy: 0.6341 - val_loss: 0.6518 - learning_rate: 0.0010
# Epoch 2/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6942 - loss: 0.5671
# Epoch 2: val_accuracy improved from 0.63415 to 0.64634, saving model to models/best_phoneme_model.keras
#
# Epoch 2: finished saving model to models/best_phoneme_model.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6708 - loss: 0.5869 - val_accuracy: 0.6463 - val_loss: 0.6023 - learning_rate: 0.0010
# Epoch 3/20
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7925 - loss: 0.4769
# Epoch 3: val_accuracy improved from 0.64634 to 0.78049, saving model to models/best_phoneme_model.keras
#
# Epoch 3: finished saving model to models/best_phoneme_model.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7969 - loss: 0.4765 - val_accuracy: 0.7805 - val_loss: 0.5614 - learning_rate: 0.0010
# Epoch 4/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8179 - loss: 0.4107
# Epoch 4: val_accuracy improved from 0.78049 to 0.80488, saving model to models/best_phoneme_model.keras
#
# Epoch 4: finished saving model to models/best_phoneme_model.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8369 - loss: 0.3791 - val_accuracy: 0.8049 - val_loss: 0.5244 - learning_rate: 0.0010
# Epoch 5/20
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8886 - loss: 0.2737
# Epoch 5: val_accuracy did not improve from 0.80488
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8923 - loss: 0.2648 - val_accuracy: 0.7927 - val_loss: 0.5081 - learning_rate: 0.0010
# Epoch 6/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9354 - loss: 0.1916
# Epoch 6: val_accuracy did not improve from 0.80488
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9415 - loss: 0.1839 - val_accuracy: 0.7805 - val_loss: 0.5011 - learning_rate: 0.0010
# Epoch 7/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9703 - loss: 0.1266
# Epoch 7: val_accuracy did not improve from 0.80488
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9569 - loss: 0.1441 - val_accuracy: 0.7439 - val_loss: 0.4623 - learning_rate: 0.0010
# Epoch 8/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9444 - loss: 0.1322
# Epoch 8: val_accuracy did not improve from 0.80488
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9477 - loss: 0.1248 - val_accuracy: 0.6951 - val_loss: 0.4823 - learning_rate: 0.0010
# Epoch 9/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9896 - loss: 0.0732
# Epoch 9: val_accuracy improved from 0.80488 to 0.82927, saving model to models/best_phoneme_model.keras
#
# Epoch 9: finished saving model to models/best_phoneme_model.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9785 - loss: 0.0794 - val_accuracy: 0.8293 - val_loss: 0.3940 - learning_rate: 0.0010
# Epoch 10/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9839 - loss: 0.0633
# Epoch 10: val_accuracy did not improve from 0.82927
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9908 - loss: 0.0454 - val_accuracy: 0.8171 - val_loss: 0.3854 - learning_rate: 0.0010
# Epoch 11/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9692 - loss: 0.1024
# Epoch 11: val_accuracy improved from 0.82927 to 0.85366, saving model to models/best_phoneme_model.keras
#
# Epoch 11: finished saving model to models/best_phoneme_model.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9754 - loss: 0.0829 - val_accuracy: 0.8537 - val_loss: 0.3465 - learning_rate: 0.0010
# Epoch 12/20
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9711 - loss: 0.0756
# Epoch 12: val_accuracy did not improve from 0.85366
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9754 - loss: 0.0695 - val_accuracy: 0.7805 - val_loss: 0.3953 - learning_rate: 0.0010
# Epoch 13/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9994 - loss: 0.0269
# Epoch 13: val_accuracy did not improve from 0.85366
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9938 - loss: 0.0339 - val_accuracy: 0.8415 - val_loss: 0.3251 - learning_rate: 0.0010
# Epoch 14/20
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9864 - loss: 0.0488
# Epoch 14: val_accuracy improved from 0.85366 to 0.90244, saving model to models/best_phoneme_model.keras
#
# Epoch 14: finished saving model to models/best_phoneme_model.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9846 - loss: 0.0541 - val_accuracy: 0.9024 - val_loss: 0.2456 - learning_rate: 0.0010
# Epoch 15/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9933 - loss: 0.0320
# Epoch 15: val_accuracy did not improve from 0.90244
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9938 - loss: 0.0352 - val_accuracy: 0.8780 - val_loss: 0.2816 - learning_rate: 0.0010
# Epoch 16/20
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9962 - loss: 0.0152
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 16: val_accuracy did not improve from 0.90244
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9938 - loss: 0.0236 - val_accuracy: 0.8902 - val_loss: 0.3053 - learning_rate: 0.0010
# Epoch 17/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9972 - loss: 0.0263
# Epoch 17: val_accuracy did not improve from 0.90244
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9969 - loss: 0.0257 - val_accuracy: 0.8902 - val_loss: 0.3141 - learning_rate: 5.0000e-04
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 14.

# %%
print("Accuracy of our model on test data : " , model.evaluate(X_test, y_test)[1]*100 , "%")

epochs = range(len(history.history['loss']))
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Validation Loss')
ax[0].set_title('Training & Validation Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Validation Accuracy')
ax[1].set_title('Training & Validation Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9024 - loss: 0.2456
# Accuracy of our model on test data :  90.24389982223511 %

# %%
y_pred_probs = model.predict(X_test)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step

# %%
# Calculate ROC curve
fpr, tpr, _ = roc_curve(y_test, y_pred_probs)
roc_auc = roc_auc_score(y_test, y_pred_probs)

# Plot ROC curve
plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random Classifier')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.grid(alpha=0.3)
plt.show()

print(f"AUC Score: {roc_auc:.4f}")
# Out:
# AUC Score: 0.9532

# %%
# Method 1: Youden's J statistic (maximize TPR - FPR)
j_scores = tpr - fpr
optimal_idx = np.argmax(j_scores)
optimal_threshold = _[optimal_idx]

print(f"Threshold = {optimal_threshold:.4f} (optimal)")
y_pred_optimal = np.where(y_pred_probs >= optimal_threshold, 1,0).astype(int)
print(f"Accuracy: {accuracy_score(y_test, y_pred_optimal) * 100:.2f}%")
# Out:
# Threshold = 0.3565 (optimal)
# Accuracy: 93.90%

# %%
print(classification_report(y_test, y_pred_optimal))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.87      0.91        30
#            1       0.93      0.98      0.95        52
#
#     accuracy                           0.94        82
#    macro avg       0.95      0.92      0.93        82
# weighted avg       0.94      0.94      0.94        82

# %%
cm = confusion_matrix(y_test, y_pred_optimal)
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=["Normal","Scam"],
            yticklabels=["Normal","Scam"])

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
import numpy as np
from tensorflow.keras.models import load_model

model = load_model('models/best_phoneme_model.keras')

path = r'features\NORMAL_CALLS\mfcc_normal_20_00007.npy'

feature = np.load(path)

feature.shape
# Out:
# (122, 120)

# %%
feature = pad_features(feature)
feature.shape
# Out:
# (420, 120)

# %%
feature = np.expand_dims(feature, axis=0)
feature.shape
# Out:
# (1, 420, 120)

# %%
model.predict(feature)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# array([[0.04236651]], dtype=float32)
